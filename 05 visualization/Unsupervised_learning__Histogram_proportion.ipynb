# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = 1000
data = np.exp( np.random.randn(n)/2 )

# %%
k = 40
y,x = np.histogram(data,bins=k)

xx = (x[1:]+x[:-1])/2
yy = (y*100)/sum(y)

# %%
# plt.plot(xx,y)
plt.bar(xx,yy)
plt.show()
